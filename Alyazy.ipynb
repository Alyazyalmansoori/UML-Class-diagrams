# %%
# create class Admin
class Admin:

    # Creating constructor to initialize Admin object
    def __init__(self, name, passenger_id, boarding_id, flight_no, ticket_number):
        self.name = name
        self.passenger_id = passenger_id
        self.boarding_id = boarding_id
        self.flight_no = flight_no
        self.ticket_number = ticket_number

    def get_name(self):
        # Getter method for retrieving admin name
        return self.name

    def get_flight_no(self):
        # Getter method for retrieving flight number
        return self.flight_no

    def get_passenger_id(self):
        return self.passenger_id

    def get_boarding_id(self):
        return self.boarding_id

    def set_name(self, new_name):
        # Setter method for updating admin name
        self.name = new_name

    def set_passenger_id(self, new_passenger_id):
        self.passenger_id = new_passenger_id

    def set_boarding_id(self, new_boarding_id):
        self.boarding_id = new_boarding_id

    def set_flight_no(self, new_flight_no):
        # Setter method for updating flight number
        self.flight_no = new_flight_no

    def verify_passenger(self):
        # Placeholder function for verifying passenger
        pass

#create class Passenger

class Passenger:
    def __init__(self, name, passenger_id, seat_number, booking_id, ticket_number):
        # Constructor for the Passenger class.
        self._name = name
        self._passenger_id = passenger_id
        self._seat_number = seat_number
        self._booking_id = booking_id
        self._ticket_number = ticket_number

    def get_name(self):
        # Getter method for name attribute.
        return self._name

    def set_name(self, name):
        # Setter method for name attribute.
        self._name = name

    def get_passenger_id(self):
        # Getter method for passenger ID attribute.
        return self._passenger_id

    def set_passenger_id(self, passenger_id):
        # Setter method for passenger ID attribute.
        self._passenger_id = passenger_id

    def get_seat_number(self):
        # Getter method for seat number attribute.
        return self._seat_number

    def set_seat_number(self, seat_number):
        # Setter method for seat number attribute.
        self._seat_number = seat_number

    def get_booking_id(self):
        # Getter method for booking ID attribute.
        return self._booking_id

    def set_booking_id(self, booking_id):
        # Setter method for booking ID attribute.
        self._booking_id = booking_id

    def get_ticket_number(self):
        # Getter method for ticket number attribute.
        return self._ticket_number

    def set_ticket_number(self, ticket_number):
        # Setter method for ticket number attribute.
        self._ticket_number = ticket_number

    def book_flight(self):
        # Placeholder function for future implementation
        pass


class Flight:
    def __init__(self, flight_number, departure_airport, destination_airport, departure_date_time, arrival_date_time, gate):
        # Initialize Flight object with flight details
        self.flight_number = flight_number
        self.departure_airport = departure_airport
        self.destination_airport = destination_airport
        self.departure_date_time = departure_date_time
        self.arrival_date_time = arrival_date_time
        self.gate = gate

    def get_flight_number(self):
        # Getter method for retrieving flight number
        return self.flight_number

    def get_departure_airport(self):
        # Getter method for retrieving departure airport
        return self.departure_airport

    def get_destination_airport(self):
        # Getter method for retrieving destination airport
        return self.destination_airport

    def get_departure_date_time(self):
        # Getter method for retrieving departure date and time
        return self.departure_date_time

    def get_arrival_date_time(self):
        # Getter method for retrieving arrival date and time
        return self.arrival_date_time

    def get_gate(self):
        # Getter method for retrieving gate information
        return self.gate

    def set_flight_number(self, new_flight_number):
        # Setter method for updating flight number
        self.flight_number = new_flight_number

    def set_departure_airport(self, new_departure_airport):
        # Setter method for updating departure airport
        self.departure_airport = new_departure_airport

    def set_destination_airport(self, new_destination_airport):
        # Setter method for updating destination airport
        self.destination_airport = new_destination_airport

    def set_departure_date_time(self, new_departure_date_time):
        # Setter method for updating departure date and time
        self.departure_date_time = new_departure_date_time

    def set_arrival_date_time(self, new_arrival_date_time):
        # Setter method for updating arrival date and time
        self.arrival_date_time = new_arrival_date_time

    def set_gate(self, new_gate):
        # Setter method for updating gate information
        self.gate = new_gate

    def some_function(self):
        # Placeholder function for future implementation
        pass


class BoardingPass:
    # Constructor of BoardingPass class
    def __init__(self,  passenger_name, flight_number, departure_airport, destination_airport,
                 departure_date_time, arrival_date_time, boarding_time, seat_number, gate_number, terminal_number,
                 electronic_ticket):
        # Initialize BoardingPass object with provided attributes
        #self.boarding_pass_id = boarding_pass_id
        self.passenger_name = passenger_name
        self.flight_number = flight_number
        self.departure_airport = departure_airport
        self.destination_airport = destination_airport
        self.departure_date_time = departure_date_time
        self.arrival_date_time = arrival_date_time
        self.boarding_time = boarding_time
        self.seat_number = seat_number
        self.gate_number = gate_number
        self.terminal_number = terminal_number
        self.electronic_ticket = electronic_ticket

    # Getter methods to get attribute values
    def get_boarding_pass_id(self):
        return self.boarding_pass_id

    def get_passenger_name(self):
        return self.passenger_name

    def get_flight_number(self):
        return self.flight_number

    def get_departure_airport(self):
        return self.departure_airport

    def get_destination_airport(self):
        return self.destination_airport

    def get_departure_date_time(self):
        return self.departure_date_time

    def get_arrival_date_time(self):
        return self.arrival_date_time

    def get_boarding_time(self):
        return self.boarding_time

    def get_seat_number(self):
        return self.seat_number

    def get_gate_number(self):
        return self.gate_number

    def get_terminal_number(self):
        return self.terminal_number

    def get_electronic_ticket(self):
        return self.electronic_ticket

    #  function to retrieve flight details
    def get_flight_details(self):
        pass
    # function to retrieve passenger details
    def get_passenger_details(self):
        pass

# %%
from datetime import datetime
# Create objects for each class
admin = Admin("Maryam Saeed", "FL123", "B123", "TKT123", "T123")
passenger = Passenger("Alyazy", "TKT123", "A23", "B123", "T123" )
flight = Flight("FL123", "DXB", "LGW", datetime(2024, 2, 25, 12, 0), datetime(2024, 2, 25, 15, 0), "A12")
boarding_pass = BoardingPass("Alyazy", "FL123", "DXB", "LGW", datetime(2024, 2, 25, 12, 0), datetime(2024, 2, 25, 15, 0), "A12", "09A", "03", "2", "629")

# Display all boarding pass details
print("Boarding Pass Details:")
print("Passenger Name:", boarding_pass.get_passenger_name())
print("Flight Number:", boarding_pass.get_flight_number())
print("Departure Airport:", boarding_pass.get_departure_airport())
print("Destination Airport:", boarding_pass.get_destination_airport())
print("Departure Date & Time:", boarding_pass.get_departure_date_time())
print("Arrival Date & Time:", boarding_pass.get_arrival_date_time())
print("Gate:", boarding_pass.get_gate_number())
print("Seat Number:", boarding_pass.get_seat_number())
print("Terminal Number:", boarding_pass.get_terminal_number())
print("Electronic Ticket:", boarding_pass.get_electronic_ticket())
# Out:
# Boarding Pass Details:
# Passenger Name: Alyazy
# Flight Number: FL123
# Departure Airport: DXB
# Destination Airport: LGW
# Departure Date & Time: 2024-02-25 12:00:00
# Arrival Date & Time: 2024-02-25 15:00:00
# Gate: 03
# Seat Number: 09A
# Terminal Number: 2
# Electronic Ticket: 629

# %%
# Update the arrival date and time of the flight
flight.set_arrival_date_time(datetime(2024, 2, 25, 16, 0))

# Display the updated arrival date and time
print("Updated Arrival Date & Time:", flight.get_arrival_date_time())
# Out:
# Updated Arrival Date & Time: 2024-02-25 16:00:00

# %%
from datetime import datetime

# Create objects for each class
admin = Admin("Maryam Saeed", "FL123", "B123", "TKT123", "T123")
# Incomplete passenger information with missing seat number
passenger = Passenger("Alyazy", "TKT123", "A23", "", "T123" )  # Empty seat number
flight = Flight("FL123", "DXB", "LGW", datetime(2024, 2, 25, 12, 0), datetime(2024, 2, 25, 15, 0), "A12")

# Attempt to create a boarding pass with incomplete passenger information
if (passenger.get_seat_number() == "" or passenger.get_name() == "" or
    passenger.get_passenger_id() == "" or passenger.get_booking_id() == "" or
    passenger.get_ticket_number() == ""):
    print("Incomplete passenger details. Please provide all required information.")
else:
    try:
        boarding_pass = BoardingPass(passenger.get_name(), flight.get_flight_number(), flight.get_departure_airport(),
                                     flight.get_destination_airport(), flight.get_departure_date_time(),
                                     flight.get_arrival_date_time(), "A12", passenger.get_seat_number(), "B123", "Terminal 1",
                                     "ET123")
        print("Boarding Pass Details:")
        print("Passenger Name:", boarding_pass.get_passenger_name())
        print("Flight Number:", boarding_pass.get_flight_number())
        print("Departure Airport:", boarding_pass.get_departure_airport())
        print("Destination Airport:", boarding_pass.get_destination_airport())
        print("Departure Date & Time:", boarding_pass.get_departure_date_time())
        print("Arrival Date & Time:", boarding_pass.get_arrival_date_time())
        print("Gate:", boarding_pass.get_boarding_time())  # Change to get_boarding_time()
        print("Seat Number:", boarding_pass.get_seat_number())
        print("Electronic Ticket:", boarding_pass.get_electronic_ticket())

    except ValueError as e:
        print("Error:", e)
# Out:
# Incomplete passenger details. Please provide all required information.
